# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
ad=pd.read_csv("/content/Advertising.csv")

# %%
ad.head()

# %%
ad=ad.iloc[:,1:]

# %%
ad.head()

# %%
x1=ad.iloc[:,0]
x1.head()

# %%
y1=ad.iloc[:,3]
y1.head()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x1,y1,test_size=0.2,random_state=2)

# %%
x_train.shape

# %%
x_test.shape

# %%
sns.scatterplot(ad,x=x1,y=y1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr.fit(x_train.values.reshape(-1,1),y_train)

# %%
lr.predict(x_test.values.reshape(-1,1))

# %%
y_test.values

# %%
sns.scatterplot(ad,x=x1,y=y1)
plt.plot(x_train,lr.predict(x_train.values.reshape(-1,1)))

# %%
bs=pd.read_csv("/content/boston_data.csv")

# %%
class lr:
  def __init__(self):

    self.m=None
    self.c=None

  def fit(self,x_train,y_train):
    num=0
    den=0

    for i in range(x_train.shape[0]):
      num=num + (x_train.iloc[0] - x_train.mean()) * (y_train.iloc[i] -y_train.mean())
      den=den + (x_train.iloc[0] - x_train.mean()) * (y_train.iloc[i] -y_train.mean())
    self.m=num/den
    self.c=y_train.mean() - self.m  * x_train.mean()
    print(self.m,self.c)

# %%
lr1=lr()

# %%
lr1.fit(x_train,y_train)

# %%
y_pred=lr1.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
